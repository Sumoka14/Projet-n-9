# %%
import pandas as pd
import numpy as np

# %%
pop = pd.read_csv('data\FAOSTAT_Population_2017_2020.csv')
alim = pd.read_csv('data\FAOSTAT_DisponibiliteAlimentaire_2017-2020.csv')
stabilite = pd.read_csv('data\FAOSTAT_Stabilité_politique.csv')
pib = pd.read_csv('data\FAOSTAT_data_Pib_habitants.csv')
prodVolail = pd.read_csv('data\FAOSTAT_Production_Volailles.csv')

# %%
annee = 2020

# %% [markdown]
# # Nettoyage des Données

# %%
pop
# Out:
#     Code Domaine                      Domaine  Code zone (M49)  \
# 0            FBS  Bilans Alimentaires (2010-)                4
# 1            FBS  Bilans Alimentaires (2010-)                4
# 2            FBS  Bilans Alimentaires (2010-)                4
# 3            FBS  Bilans Alimentaires (2010-)                4
# 4            FBS  Bilans Alimentaires (2010-)              710
# ..           ...                          ...              ...
# 727          FBS  Bilans Alimentaires (2010-)              894
# 728          FBS  Bilans Alimentaires (2010-)              716
# 729          FBS  Bilans Alimentaires (2010-)              716
# 730          FBS  Bilans Alimentaires (2010-)              716
# 731          FBS  Bilans Alimentaires (2010-)              716
#
#                Zone  Code Élément            Élément Code Produit (CPC)  \
# 0       Afghanistan           511  Population totale              S2501
# 1       Afghanistan           511  Population totale              S2501
# 2       Afghanistan           511  Population totale              S2501
# 3       Afghanistan           511  Population totale              S2501
# 4    Afrique du Sud           511  Population totale              S2501
# ..              ...           ...                ...                ...
# 727          Zambie           511  Population totale              S2501
# 728        Zimbabwe           511  Population totale              S2501
# 729        Zimbabwe           511  Population totale              S2501
# 730        Zimbabwe           511  Population totale              S2501
# 731        Zimbabwe           511  Population totale              S2501
#
#         Produit  Code année  Année           Unité    Valeur Symbole  \
# 0    Population        2017   2017  1000 personnes  36296.00       X
# 1    Population        2018   2018  1000 personnes  37172.00       X
# 2    Population        2019   2019  1000 personnes  38041.75       X
# 3    Population        2020   2020  1000 personnes  38928.35       X
# 4    Population        2017   2017  1000 personnes  57010.00       X
# ..          ...         ...    ...             ...       ...     ...
# 727  Population        2020   2020  1000 personnes  18383.96       X
# 728  Population        2017   2017  1000 personnes  14236.59       X
# 729  Population        2018   2018  1000 personnes  14438.80       X
# 730  Population        2019   2019  1000 personnes  14645.47       X
# 731  Population        2020   2020  1000 personnes  14862.92       X
#
#                 Description du Symbole
# 0    Ciffre de sources internationales
# 1    Ciffre de sources internationales
# 2    Ciffre de sources internationales
# 3    Ciffre de sources internationales
# 4    Ciffre de sources internationales
# ..                                 ...
# 727  Ciffre de sources internationales
# 728  Ciffre de sources internationales
# 729  Ciffre de sources internationales
# 730  Ciffre de sources internationales
# 731  Ciffre de sources internationales
#
# [732 rows x 14 columns]

# %%
pop.describe(include='all')
# Out:
#        Code Domaine                      Domaine  Code zone (M49)  \
# count           732                          732       732.000000
# unique            1                            1              NaN
# top             FBS  Bilans Alimentaires (2010-)              NaN
# freq            732                          732              NaN
# mean            NaN                          NaN       425.740437
# std             NaN                          NaN       251.145689
# min             NaN                          NaN         4.000000
# 25%             NaN                          NaN       204.000000
# 50%             NaN                          NaN       418.000000
# 75%             NaN                          NaN       642.000000
# max             NaN                          NaN       894.000000
#
#                Zone  Code Élément            Élément Code Produit (CPC)  \
# count           732         732.0                732                732
# unique          186           NaN                  1                  1
# top     Afghanistan           NaN  Population totale              S2501
# freq              4           NaN                732                732
# mean            NaN         511.0                NaN                NaN
# std             NaN           0.0                NaN                NaN
# min             NaN         511.0                NaN                NaN
# 25%             NaN         511.0                NaN                NaN
# 50%             NaN         511.0                NaN                NaN
# 75%             NaN         511.0                NaN                NaN
# max             NaN         511.0                NaN                NaN
#
#            Produit   Code année        Année           Unité        Valeur  \
# count          732   732.000000   732.000000             732  7.320000e+02
# unique           1          NaN          NaN               1           NaN
# top     Population          NaN          NaN  1000 personnes           NaN
# freq           732          NaN          NaN             732           NaN
# mean           NaN  2018.516393  2018.516393             NaN  4.963196e+04
# std            NaN     1.118678     1.118678             NaN  1.829714e+05
# min            NaN  2017.000000  2017.000000             NaN  1.076000e+01
# 25%            NaN  2018.000000  2018.000000             NaN  2.529315e+03
# 50%            NaN  2019.000000  2019.000000             NaN  9.738060e+03
# 75%            NaN  2020.000000  2020.000000             NaN  3.108095e+04
# max            NaN  2020.000000  2020.000000             NaN  1.471287e+06
#
#        Symbole             Description du Symbole
# count      732                                732
# unique       1                                  1
# top          X  Ciffre de sources internationales
# freq       732                                732
# mean       NaN                                NaN
# std        NaN                                NaN
# min        NaN                                NaN
# 25%        NaN                                NaN
# 50%        NaN                                NaN
# 75%        NaN                                NaN
# max        NaN                                NaN

# %% [markdown]
# On commence par enlever les colonnes qui ne nous servent pas, à savoir tout sauf l'année, le pays et le nombre d'habitants qu'on prend soin de multiplier par 1000 afin d'obtenir le nombre exact d'habitants.

# %%
pop = pop[['Zone', 'Année', 'Valeur']]
pop['Valeur'] = pop['Valeur']*1000
pop = pop.rename(columns={'Zone': 'Pays',
                          'Valeur': 'Population'})
# Out:
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\1716358708.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop['Valeur'] = pop['Valeur']*1000

# %% [markdown]
# On ajoute une colonne qui servira de clé primaire

# %%
pop['id'] = pop['Pays'] + "/" + pop['Année'].astype('str')

# %%
pop
# Out:
#                Pays  Année  Population                   id
# 0       Afghanistan   2017  36296000.0     Afghanistan/2017
# 1       Afghanistan   2018  37172000.0     Afghanistan/2018
# 2       Afghanistan   2019  38041750.0     Afghanistan/2019
# 3       Afghanistan   2020  38928350.0     Afghanistan/2020
# 4    Afrique du Sud   2017  57010000.0  Afrique du Sud/2017
# ..              ...    ...         ...                  ...
# 727          Zambie   2020  18383960.0          Zambie/2020
# 728        Zimbabwe   2017  14236590.0        Zimbabwe/2017
# 729        Zimbabwe   2018  14438800.0        Zimbabwe/2018
# 730        Zimbabwe   2019  14645470.0        Zimbabwe/2019
# 731        Zimbabwe   2020  14862920.0        Zimbabwe/2020
#
# [732 rows x 4 columns]

# %% [markdown]
# On vérifie que la clé est bien unique

# %%
def EstPrimaire(df, id):
    if df[id].nunique() == len(df):
        print("La clé est bien unique")
    else:
        print("la clé n'est pas unique")


EstPrimaire(pop, 'id')
# Out:
# La clé est bien unique

# %% [markdown]
# On s'occupe de la table "stabilite" qui concerne la stabilité politique du pays

# %%
stabilite
# Out:
#      Code Domaine                             Domaine  Code zone (M49)  \
# 0              FS  Données de la sécurité alimentaire                4
# 1              FS  Données de la sécurité alimentaire                4
# 2              FS  Données de la sécurité alimentaire                4
# 3              FS  Données de la sécurité alimentaire                4
# 4              FS  Données de la sécurité alimentaire                4
# ...           ...                                 ...              ...
# 3903           FS  Données de la sécurité alimentaire              716
# 3904           FS  Données de la sécurité alimentaire              716
# 3905           FS  Données de la sécurité alimentaire              716
# 3906           FS  Données de la sécurité alimentaire              716
# 3907           FS  Données de la sécurité alimentaire              716
#
#              Zone  Code Élément Élément  Code Produit  \
# 0     Afghanistan          6125  Valeur         21032
# 1     Afghanistan          6125  Valeur         21032
# 2     Afghanistan          6125  Valeur         21032
# 3     Afghanistan          6125  Valeur         21032
# 4     Afghanistan          6125  Valeur         21032
# ...           ...           ...     ...           ...
# 3903     Zimbabwe          6125  Valeur         21032
# 3904     Zimbabwe          6125  Valeur         21032
# 3905     Zimbabwe          6125  Valeur         21032
# 3906     Zimbabwe          6125  Valeur         21032
# 3907     Zimbabwe          6125  Valeur         21032
#
#                                                 Produit  Code année  Année  \
# 0     Stabilité politique et absence de violence/ter...        2000   2000
# 1     Stabilité politique et absence de violence/ter...        2002   2002
# 2     Stabilité politique et absence de violence/ter...        2003   2003
# 3     Stabilité politique et absence de violence/ter...        2004   2004
# 4     Stabilité politique et absence de violence/ter...        2005   2005
# ...                                                 ...         ...    ...
# 3903  Stabilité politique et absence de violence/ter...        2016   2016
# 3904  Stabilité politique et absence de violence/ter...        2017   2017
# 3905  Stabilité politique et absence de violence/ter...        2018   2018
# 3906  Stabilité politique et absence de violence/ter...        2019   2019
# 3907  Stabilité politique et absence de violence/ter...        2020   2020
#
#        Unité  Valeur Symbole             Description du Symbole  Note
# 0     indice   -2.44       X  Ciffre de sources internationales   NaN
# 1     indice   -2.04       X  Ciffre de sources internationales   NaN
# 2     indice   -2.20       X  Ciffre de sources internationales   NaN
# 3     indice   -2.30       X  Ciffre de sources internationales   NaN
# 4     indice   -2.07       X  Ciffre de sources internationales   NaN
# ...      ...     ...     ...                                ...   ...
# 3903  indice   -0.62       X  Ciffre de sources internationales   NaN
# 3904  indice   -0.71       X  Ciffre de sources internationales   NaN
# 3905  indice   -0.72       X  Ciffre de sources internationales   NaN
# 3906  indice   -0.96       X  Ciffre de sources internationales   NaN
# 3907  indice   -1.08       X  Ciffre de sources internationales   NaN
#
# [3908 rows x 15 columns]

# %% [markdown]
# On ignore ce qui ne nous sert pas

# %%
stabilite = stabilite[['Zone', 'Année', 'Valeur']]

# %% [markdown]
# On crée une clé primaire comme précédemment

# %%
stabilite['id'] = stabilite['Zone']+"/" + stabilite['Année'].astype('str')
stabilite = stabilite.rename(columns={'Zone': 'Pays',
                                      'Valeur': 'Stabilité Politique'})
EstPrimaire(stabilite, 'id')
# Out:
# La clé est bien unique
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\3708130892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stabilite['id'] = stabilite['Zone']+"/" + stabilite['Année'].astype('str')

# %%
stabilite.describe()
# Out:
#              Année  Stabilité Politique
# count  3908.000000          3908.000000
# mean   2010.542733            -0.050000
# std       5.827217             0.997415
# min    2000.000000            -3.310000
# 25%    2006.000000            -0.710000
# 50%    2011.000000             0.055000
# 75%    2016.000000             0.800000
# max    2020.000000             1.970000

# %% [markdown]
# On s'occupe de la table pib qui contient le pib par habitant

# %%
pib.describe(include='all')
# Out:
#        Code Domaine                             Domaine    Code zone     Zone  \
# count          2533                                2533  2533.000000     2533
# unique            1                                   1          NaN      232
# top              FS  Données de la sécurité alimentaire          NaN  Myanmar
# freq           2533                                2533          NaN       11
# mean            NaN                                 NaN  1147.318595      NaN
# std             NaN                                 NaN  2149.175706      NaN
# min             NaN                                 NaN     1.000000      NaN
# 25%             NaN                                 NaN    84.000000      NaN
# 50%             NaN                                 NaN   156.000000      NaN
# 75%             NaN                                 NaN   235.000000      NaN
# max             NaN                                 NaN  9011.000000      NaN
#
#         Code Élément Élément  Code Produit  \
# count         2533.0    2533        2533.0
# unique           NaN       1           NaN
# top              NaN  Valeur           NaN
# freq             NaN    2533           NaN
# mean          6126.0     NaN       22013.0
# std              0.0     NaN           0.0
# min           6126.0     NaN       22013.0
# 25%           6126.0     NaN       22013.0
# 50%           6126.0     NaN       22013.0
# 75%           6126.0     NaN       22013.0
# max           6126.0     NaN       22013.0
#
#                                                   Produit   Code année  \
# count                                                2533  2533.000000
# unique                                                  1          NaN
# top     PIB par habitant, ($ PPA internationaux consta...          NaN
# freq                                                 2533          NaN
# mean                                                  NaN  2015.003948
# std                                                   NaN     5.442358
# min                                                   NaN  2000.000000
# 25%                                                   NaN  2013.000000
# 50%                                                   NaN  2016.000000
# 75%                                                   NaN  2019.000000
# max                                                   NaN  2021.000000
#
#               Année Unité         Valeur Symbole  \
# count   2533.000000  2533    2533.000000    2533
# unique          NaN     1            NaN       1
# top             NaN    I$            NaN       X
# freq            NaN  2533            NaN    2533
# mean    2015.003948   NaN   19464.324872     NaN
# std        5.442358   NaN   20625.032001     NaN
# min     2000.000000   NaN     630.700000     NaN
# 25%     2013.000000   NaN    4527.700000     NaN
# 50%     2016.000000   NaN   12357.900000     NaN
# 75%     2019.000000   NaN   27797.100000     NaN
# max     2021.000000   NaN  161972.000000     NaN
#
#                    Description du Symbole  Note
# count                                2533   0.0
# unique                                  1   NaN
# top     Ciffre de sources internationales   NaN
# freq                                 2533   NaN
# mean                                  NaN   NaN
# std                                   NaN   NaN
# min                                   NaN   NaN
# 25%                                   NaN   NaN
# 50%                                   NaN   NaN
# 75%                                   NaN   NaN
# max                                   NaN   NaN

# %%
pib = pib[['Zone', 'Année', 'Valeur']]
pib = pib.rename(columns={'Zone': 'Pays',
                          'Valeur': 'Pib/Habitant ($/habitant)'})

# %%
pib['id'] = pib['Pays'] + "/" + pib['Année'].astype('str')
EstPrimaire(pib, 'id')
# Out:
# La clé est bien unique

# %%
def checkUnusedId(dfToRmv, df2, id1, id2):
    listToRmv = dfToRmv[id1].tolist()
    listDf2 = df2[id2].tolist()
    tempo = []

    for i in listToRmv:
        if i in listDf2:
            tempo.append(i)
    for i in tempo:
        listToRmv.remove(i)

    if len(listToRmv) != 0:
        listToRmvUnique = pd.Series(listToRmv).unique()
        print(len(listToRmvUnique), id1, "non utilisé(s) (",
              len(listToRmv), ") :", listToRmvUnique)
    else:
        print("Auncun", id1, "non utilisé")
    # dfToRmv = dfToRmv.drop(dfToRmv[dfToRmv[id1].isin(listToRmv)].index)

    return listToRmv

# %% [markdown]
# On s'occupe de la table ProdVollail

# %%
prodVolail
# Out:
#      Code Domaine                       Domaine  Code zone (M49)         Zone  \
# 0             QCL  Cultures et produits animaux                4  Afghanistan
# 1             QCL  Cultures et produits animaux                4  Afghanistan
# 2             QCL  Cultures et produits animaux                4  Afghanistan
# 3             QCL  Cultures et produits animaux                4  Afghanistan
# 4             QCL  Cultures et produits animaux                4  Afghanistan
# ...           ...                           ...              ...          ...
# 1143          QCL  Cultures et produits animaux              716     Zimbabwe
# 1144          QCL  Cultures et produits animaux              716     Zimbabwe
# 1145          QCL  Cultures et produits animaux              716     Zimbabwe
# 1146          QCL  Cultures et produits animaux              716     Zimbabwe
# 1147          QCL  Cultures et produits animaux              716     Zimbabwe
#
#       Code Élément     Élément  Code Produit (CPC)  \
# 0             5112    Réserves                2151
# 1             5112    Réserves                2151
# 2             5112    Réserves                2151
# 3             5510  Production               21121
# 4             5510  Production               21121
# ...            ...         ...                 ...
# 1143          5112    Réserves                2151
# 1144          5112    Réserves                2151
# 1145          5510  Production               21121
# 1146          5510  Production               21121
# 1147          5510  Production               21121
#
#                                     Produit  Code année  Année       Unité  \
# 0                                   Poulets        2018   2018  1000 têtes
# 1                                   Poulets        2019   2019  1000 têtes
# 2                                   Poulets        2020   2020  1000 têtes
# 3     Viande, poulet, fraîche ou réfrigérée        2018   2018      tonnes
# 4     Viande, poulet, fraîche ou réfrigérée        2019   2019      tonnes
# ...                                     ...         ...    ...         ...
# 1143                                Poulets        2019   2019  1000 têtes
# 1144                                Poulets        2020   2020  1000 têtes
# 1145  Viande, poulet, fraîche ou réfrigérée        2018   2018      tonnes
# 1146  Viande, poulet, fraîche ou réfrigérée        2019   2019      tonnes
# 1147  Viande, poulet, fraîche ou réfrigérée        2020   2020      tonnes
#
#          Valeur Symbole Description du Symbole
# 0      14479.00       I         Valeur imputée
# 1      13735.00       I         Valeur imputée
# 2      13697.00       I         Valeur imputée
# 3      29434.79       I         Valeur imputée
# 4      27877.47       I         Valeur imputée
# ...         ...     ...                    ...
# 1143   17000.00       E         Valeur estimée
# 1144   16200.00       E         Valeur estimée
# 1145  103302.87       I         Valeur imputée
# 1146  114344.00       A       Chiffre officiel
# 1147  111546.00       A       Chiffre officiel
#
# [1148 rows x 14 columns]

# %%
prodVolail = prodVolail.pivot_table(index=["Zone", "Année"], columns=[
                                    "Élément", "Unité", "Produit"], values="Valeur").droplevel(0, axis=1).droplevel(0, axis=1).reset_index()
prodVolail = prodVolail.rename(columns={"Zone": "Pays", "Poulets": "Milliers de poulets",
                               "Viande, poulet, fraîche ou réfrigérée": "Tonnes de viande de poulet produite"})

# %%
prodVolail
# Out:
# Produit            Pays  Année  Tonnes de viande de poulet produite  \
# 0           Afghanistan   2018                             29434.79
# 1           Afghanistan   2019                             27877.47
# 2           Afghanistan   2020                             27753.95
# 3        Afrique du Sud   2018                           1743285.00
# 4        Afrique du Sud   2019                           1814000.00
# ..                  ...    ...                                  ...
# 582           Îles Cook   2019                                16.45
# 583           Îles Cook   2020                                15.88
# 584        Îles Salomon   2018                               284.68
# 585        Îles Salomon   2019                               283.99
# 586        Îles Salomon   2020                               283.68
#
# Produit  Milliers de poulets
# 0                    14479.0
# 1                    13735.0
# 2                    13697.0
# 3                   173352.0
# 4                   170252.0
# ..                       ...
# 582                     18.0
# 583                     17.0
# 584                    244.0
# 585                    245.0
# 586                    245.0
#
# [587 rows x 4 columns]

# %%
prodVolail.isna().mean()
# Out:
# Produit
# Pays                                   0.000000
# Année                                  0.000000
# Tonnes de viande de poulet produite    0.001704
# Milliers de poulets                    0.042589
# dtype: float64

# %%
prodVolail[prodVolail["Tonnes de viande de poulet produite"].isna()][[
    'Pays', 'Année']]
# Out:
# Produit       Pays  Année
# 472      Slovaquie   2020

# %%
prodVolail = prodVolail.dropna(subset=['Tonnes de viande de poulet produite'])

# %%
prodVolail[prodVolail["Milliers de poulets"].isna()][['Pays', 'Année']]
# Out:
# Produit       Pays  Année
# 12       Allemagne   2018
# 13       Allemagne   2019
# 14       Allemagne   2020
# 33        Autriche   2018
# 34        Autriche   2019
# 35        Autriche   2020
# 77        Bulgarie   2020
# 122         Chypre   2020
# 146       Danemark   2020
# 153        Espagne   2018
# 154        Espagne   2019
# 155        Espagne   2020
# 187          Grèce   2019
# 188          Grèce   2020
# 228        Irlande   2018
# 229        Irlande   2019
# 230        Irlande   2020
# 237         Italie   2018
# 238         Italie   2019
# 239         Italie   2020
# 269       Lettonie   2020
# 300          Malte   2018
# 301          Malte   2019
# 302          Malte   2020
# 508       Tchéquie   2020

# %% [markdown]
# Étant donné qu'il manque les données des 3 années sur quasiment chaque pays de la liste, on va tout simplement les estimer à la médiane.

# %%
prodVolail["Milliers de poulets"] = prodVolail["Milliers de poulets"].fillna(
    prodVolail["Milliers de poulets"].median())
# Out:
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\3484537884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prodVolail["Milliers de poulets"] = prodVolail["Milliers de poulets"].fillna(

# %%
prodVolail['id'] = prodVolail['Pays'] + "/" + prodVolail['Année'].astype('str')
EstPrimaire(prodVolail, 'id')
# Out:
# La clé est bien unique
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\1966502645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prodVolail['id'] = prodVolail['Pays'] + "/" + prodVolail['Année'].astype('str')

# %%
prodVolail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 586 entries, 0 to 586
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Pays                                 586 non-null    object
#  1   Année                                586 non-null    int64
#  2   Tonnes de viande de poulet produite  586 non-null    float64
#  3   Milliers de poulets                  586 non-null    float64
#  4   id                                   586 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 27.5+ KB

# %% [markdown]
# On s'occupe maintenant de la table "alim"

# %%
alim['Année'].unique()
# Out:
# array([2017, 2018, 2019, 2020], dtype=int64)

# %% [markdown]
# On crée une copie pour pouvoir revenir à ces données plus tard

# %%
alimOri = alim.copy()

# %%
alim
# Out:
#                             Domaine         Zone  \
# 0       Bilans Alimentaires (2010-)  Afghanistan
# 1       Bilans Alimentaires (2010-)  Afghanistan
# 2       Bilans Alimentaires (2010-)  Afghanistan
# 3       Bilans Alimentaires (2010-)  Afghanistan
# 4       Bilans Alimentaires (2010-)  Afghanistan
# ...                             ...          ...
# 241475  Bilans Alimentaires (2010-)     Zimbabwe
# 241476  Bilans Alimentaires (2010-)     Zimbabwe
# 241477  Bilans Alimentaires (2010-)     Zimbabwe
# 241478  Bilans Alimentaires (2010-)     Zimbabwe
# 241479  Bilans Alimentaires (2010-)     Zimbabwe
#
#                                                   Élément          Produit  \
# 0                                 Importations - Quantité  Blé et produits
# 1                                 Importations - Quantité  Blé et produits
# 2                                 Importations - Quantité  Blé et produits
# 3                                 Importations - Quantité  Blé et produits
# 4                                 Exportations - Quantité  Blé et produits
# ...                                                   ...              ...
# 241475     Disponibilité alimentaire (Kcal/personne/jour)     Miscellanees
# 241476  Disponibilité de protéines en quantité (g/pers...     Miscellanees
# 241477  Disponibilité de protéines en quantité (g/pers...     Miscellanees
# 241478  Disponibilité de protéines en quantité (g/pers...     Miscellanees
# 241479  Disponibilité de protéines en quantité (g/pers...     Miscellanees
#
#         Année               Unité   Valeur
# 0        2017  Milliers de tonnes  3080.00
# 1        2018  Milliers de tonnes  3419.00
# 2        2019  Milliers de tonnes  2534.00
# 3        2020  Milliers de tonnes  2741.00
# 4        2017  Milliers de tonnes     2.00
# ...       ...                 ...      ...
# 241475   2020  Kcal/personne/jour     1.00
# 241476   2017     g/personne/jour     0.03
# 241477   2018     g/personne/jour     0.04
# 241478   2019     g/personne/jour     0.09
# 241479   2020     g/personne/jour     0.03
#
# [241480 rows x 7 columns]

# %% [markdown]
# On ne garde que la colonne 'nourriture' qui correspond à l'utilisation liée à l'alimentation humaine

# %%
alim = alim[alim['Élément'].isin(['Disponibilité alimentaire (Kcal/personne/jour)',
                                 'Disponibilité de protéines en quantité (g/personne/jour)'])]

# %% [markdown]
# Retirons les colonnes inutiles

# %%
alim = alim[['Zone', 'Année', 'Élément', 'Valeur', 'Produit']]
alim = alim.rename(columns={'Zone': 'Pays'})

# %% [markdown]
# Créons maintenant un tableau contenant la part de la viande animale dans la consommation en Kcal et en gramme de protéines par personne

# %%
Viande_List = ['Viande de Bovins', "Viande d'Ovins/Caprins", 'Viande de porcins',
               'Viande de Suides', "Viande de Volailles", "Viande, Autre", "Abats Comestible"]

# %% [markdown]
# Calculons d'abord la consommation totale

# %%
part = alim.groupby(['Pays', 'Année', 'Élément'])['Valeur'].sum().reset_index(
).pivot_table('Valeur', ['Pays', 'Année'], 'Élément').reset_index()
part
# Out:
# Élément            Pays  Année  \
# 0           Afghanistan   2017
# 1           Afghanistan   2018
# 2           Afghanistan   2019
# 3           Afghanistan   2020
# 4        Afrique du Sud   2017
# ..                  ...    ...
# 727            Éthiopie   2020
# 728        Îles Salomon   2017
# 729        Îles Salomon   2018
# 730        Îles Salomon   2019
# 731        Îles Salomon   2020
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                                2303.0
# 1                                                2268.0
# 2                                                2237.0
# 3                                                2239.0
# 4                                                2896.0
# ..                                                  ...
# 727                                              2406.0
# 728                                              2404.0
# 729                                              2399.0
# 730                                              2380.0
# 731                                              2357.0
#
# Élément  Disponibilité de protéines en quantité (g/personne/jour)
# 0                                                    59.51
# 1                                                    57.65
# 2                                                    56.06
# 3                                                    56.65
# 4                                                    79.68
# ..                                                     ...
# 727                                                  74.10
# 728                                                  53.42
# 729                                                  52.70
# 730                                                  51.71
# 731                                                  49.77
#
# [732 rows x 4 columns]

# %% [markdown]
# et maintenant la consommation de viande animale

# %%
alimViande = alim[alim['Produit'].isin(Viande_List)]
alimViande = alimViande.groupby(['Pays', 'Année', 'Élément'])['Valeur'].sum(
).reset_index().pivot_table('Valeur', ['Pays', 'Année'], 'Élément').reset_index()
alimViande = alimViande.rename(columns={'Disponibilité alimentaire (Kcal/personne/jour)': 'Disponibilité alimentaire (Viande) (Kcal/personne/jour)',
                                        'Disponibilité de protéines en quantité (g/personne/jour)': 'Disponibilité de protéines en quantité (Viande) (g/personne/jour)'})

# %%
part = pd.merge(part, alimViande, on=['Pays', 'Année'])

# %%
part['Part de la viande en protéine (%)'] = round(
    100*part['Disponibilité alimentaire (Viande) (Kcal/personne/jour)']/part['Disponibilité alimentaire (Kcal/personne/jour)'], 2)
part['Part de la viande en Kcal (%)'] = round(100*part['Disponibilité de protéines en quantité (Viande) (g/personne/jour)'] /
                                              part['Disponibilité de protéines en quantité (g/personne/jour)'], 2)

# %%
part = part[['Pays', 'Année',
             'Part de la viande en protéine (%)', 'Part de la viande en Kcal (%)', 'Disponibilité alimentaire (Kcal/personne/jour)']]

# %%
part['id'] = part['Pays'] + "/" + part['Année'].astype('str')

# %%
part
# Out:
# Élément            Pays  Année  Part de la viande en protéine (%)  \
# 0           Afghanistan   2017                               2.43
# 1           Afghanistan   2018                               2.29
# 2           Afghanistan   2019                               2.15
# 3           Afghanistan   2020                               2.50
# 4        Afrique du Sud   2017                              11.60
# ..                  ...    ...                                ...
# 727            Éthiopie   2020                               1.91
# 728        Îles Salomon   2017                               3.29
# 729        Îles Salomon   2018                               3.29
# 730        Îles Salomon   2019                               3.66
# 731        Îles Salomon   2020                               3.27
#
# Élément  Part de la viande en Kcal (%)  \
# 0                                 7.21
# 1                                 6.96
# 2                                 6.76
# 3                                 7.52
# 4                                33.58
# ..                                 ...
# 727                               5.09
# 728                               8.39
# 729                               8.50
# 730                               9.94
# 731                               9.68
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)                   id
# 0                                                2303.0     Afghanistan/2017
# 1                                                2268.0     Afghanistan/2018
# 2                                                2237.0     Afghanistan/2019
# 3                                                2239.0     Afghanistan/2020
# 4                                                2896.0  Afrique du Sud/2017
# ..                                                  ...                  ...
# 727                                              2406.0        Éthiopie/2020
# 728                                              2404.0    Îles Salomon/2017
# 729                                              2399.0    Îles Salomon/2018
# 730                                              2380.0    Îles Salomon/2019
# 731                                              2357.0    Îles Salomon/2020
#
# [732 rows x 6 columns]

# %%
part.describe()
# Out:
# Élément        Année  Part de la viande en protéine (%)  \
# count     732.000000                         732.000000
# mean     2018.516393                           8.323743
# std         1.118678                           4.718442
# min      2017.000000                           0.730000
# 25%      2018.000000                           4.567500
# 50%      2019.000000                           8.025000
# 75%      2020.000000                          11.440000
# max      2020.000000                          27.400000
#
# Élément  Part de la viande en Kcal (%)  \
# count                       732.000000
# mean                         21.928388
# std                          10.209244
# min                           2.510000
# 25%                          14.157500
# 50%                          22.070000
# 75%                          28.287500
# max                          54.420000
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)
# count                                        732.000000
# mean                                        2895.935792
# std                                          454.175572
# min                                         1740.000000
# 25%                                         2588.000000
# 50%                                         2892.500000
# 75%                                         3288.250000
# max                                         3920.000000

# %% [markdown]
# Regardons maintenant l'import-export de poulets

# %%
im_ex = alimOri[
    (alimOri['Produit'] == "Viande de Volailles")
    &
    (alimOri['Élément'].isin(["Importations - Quantité", "Exportations - Quantité"]))]
im_ex = im_ex[['Zone', 'Élément', 'Année', 'Valeur']]
im_ex = im_ex.pivot_table(
    'Valeur', ['Zone', 'Année'], 'Élément').reset_index().fillna(0)

im_ex['import-export (milliers de tonnes)'] = im_ex['Importations - Quantité'] - \
    im_ex['Exportations - Quantité']
im_ex = im_ex[['Zone', 'Année',
               'import-export (milliers de tonnes)']].rename(columns={"Zone": "Pays"})

im_ex['id'] = im_ex['Pays'] + "/" + im_ex['Année'].astype('str')

# %%
im_ex
# Out:
# Élément            Pays  Année  import-export (milliers de tonnes)  \
# 0           Afghanistan   2017                                29.0
# 1           Afghanistan   2018                                25.0
# 2           Afghanistan   2019                                44.0
# 3           Afghanistan   2020                                36.0
# 4        Afrique du Sud   2017                               451.0
# ..                  ...    ...                                 ...
# 727            Éthiopie   2020                                 1.0
# 728        Îles Salomon   2017                                 5.0
# 729        Îles Salomon   2018                                 5.0
# 730        Îles Salomon   2019                                 4.0
# 731        Îles Salomon   2020                                 5.0
#
# Élément                   id
# 0           Afghanistan/2017
# 1           Afghanistan/2018
# 2           Afghanistan/2019
# 3           Afghanistan/2020
# 4        Afrique du Sud/2017
# ..                       ...
# 727            Éthiopie/2020
# 728        Îles Salomon/2017
# 729        Îles Salomon/2018
# 730        Îles Salomon/2019
# 731        Îles Salomon/2020
#
# [732 rows x 4 columns]

# %% [markdown]
# Mettons ces données avec celles sur la part de la viande

# %%
checkUnusedId(part, im_ex, 'id', 'id')
checkUnusedId(im_ex, part, 'id', 'id')
# Out:
# Auncun id non utilisé
# Auncun id non utilisé
# []

# %%
part = pd.merge(
    part, im_ex[["id", "import-export (milliers de tonnes)"]], on="id")

# %%
part
# Out:
# Élément            Pays  Année  Part de la viande en protéine (%)  \
# 0           Afghanistan   2017                               2.43
# 1           Afghanistan   2018                               2.29
# 2           Afghanistan   2019                               2.15
# 3           Afghanistan   2020                               2.50
# 4        Afrique du Sud   2017                              11.60
# ..                  ...    ...                                ...
# 727            Éthiopie   2020                               1.91
# 728        Îles Salomon   2017                               3.29
# 729        Îles Salomon   2018                               3.29
# 730        Îles Salomon   2019                               3.66
# 731        Îles Salomon   2020                               3.27
#
# Élément  Part de la viande en Kcal (%)  \
# 0                                 7.21
# 1                                 6.96
# 2                                 6.76
# 3                                 7.52
# 4                                33.58
# ..                                 ...
# 727                               5.09
# 728                               8.39
# 729                               8.50
# 730                               9.94
# 731                               9.68
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)                   id  \
# 0                                                2303.0     Afghanistan/2017
# 1                                                2268.0     Afghanistan/2018
# 2                                                2237.0     Afghanistan/2019
# 3                                                2239.0     Afghanistan/2020
# 4                                                2896.0  Afrique du Sud/2017
# ..                                                  ...                  ...
# 727                                              2406.0        Éthiopie/2020
# 728                                              2404.0    Îles Salomon/2017
# 729                                              2399.0    Îles Salomon/2018
# 730                                              2380.0    Îles Salomon/2019
# 731                                              2357.0    Îles Salomon/2020
#
# Élément  import-export (milliers de tonnes)
# 0                                      29.0
# 1                                      25.0
# 2                                      44.0
# 3                                      36.0
# 4                                     451.0
# ..                                      ...
# 727                                     1.0
# 728                                     5.0
# 729                                     5.0
# 730                                     4.0
# 731                                     5.0
#
# [732 rows x 7 columns]

# %%
part.describe()
# Out:
# Élément        Année  Part de la viande en protéine (%)  \
# count     732.000000                         732.000000
# mean     2018.516393                           8.323743
# std         1.118678                           4.718442
# min      2017.000000                           0.730000
# 25%      2018.000000                           4.567500
# 50%      2019.000000                           8.025000
# 75%      2020.000000                          11.440000
# max      2020.000000                          27.400000
#
# Élément  Part de la viande en Kcal (%)  \
# count                       732.000000
# mean                         21.928388
# std                          10.209244
# min                           2.510000
# 25%                          14.157500
# 50%                          22.070000
# 75%                          28.287500
# max                          54.420000
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)  \
# count                                        732.000000
# mean                                        2895.935792
# std                                          454.175572
# min                                         1740.000000
# 25%                                         2588.000000
# 50%                                         2892.500000
# 75%                                         3288.250000
# max                                         3920.000000
#
# Élément  import-export (milliers de tonnes)
# count                            732.000000
# mean                              -7.885246
# std                              459.563869
# min                            -4220.000000
# 25%                                1.000000
# 50%                               10.000000
# 75%                               38.000000
# max                             1772.000000

# %% [markdown]
# Pour chaque pays, nous garderons :
#  <br>
#  > la poulation actuelle ainsi que son évolution par rapport à l'année passée
#  <br>
#  la stabilité politique actuelle ainsi que son évolution par rapport à l'année passée
#  <br>
#  le pib actuel ainsi que son évolution par rapport à l'année passée
#  <br>
#  la part de la viande dans les habitudes alimentaires
#  <br>
#  la quantité de poulet importée-exportée (en milliers de tonnes)
#  <br>
#  la production de volailles (en milliers de tonnes)

# %% [markdown]
# Commençons par la population

# %%
popPrec = pop[pop['Année'] == (annee-1)]
popActu = pop[pop['Année'] == annee]
checkUnusedId(popPrec, popActu, 'Pays', 'Pays')
checkUnusedId(popActu, popPrec, 'Pays', 'Pays')
print("Tous les pays sont bien restés")

popPrec['Population '+str(annee-1)] = popPrec.loc[:, 'Population']
popActu['Population '+str(annee)] = popActu.loc[:, 'Population']
popEvo = pd.merge(popPrec[['Pays', 'Population '+str(annee-1)]],
                  popActu[['Pays', 'Population '+str(annee)]], on='Pays')
popEvo['Population évolution (%)'] = 100*(popEvo['Population '+str(
    annee)]-popEvo['Population '+str(annee-1)])/popEvo['Population '+str(annee-1)]
# Out:
# Auncun Pays non utilisé
# Auncun Pays non utilisé
# Tous les pays sont bien restés
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\572468334.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popPrec['Population '+str(annee-1)] = popPrec.loc[:, 'Population']
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\572468334.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popActu['Population '+str(annee)] = popActu.loc[:, 'Population']

# %%
popEvo
# Out:
#                                        Pays  Population 2019  Population 2020  \
# 0                               Afghanistan       38041750.0       38928350.0
# 1                            Afrique du Sud       58558270.0       59308690.0
# 2                                   Albanie        2880920.0        2877800.0
# 3                                   Algérie       43053050.0       43851040.0
# 4                                 Allemagne       83517040.0       83783940.0
# ..                                      ...              ...              ...
# 181  Venezuela (République bolivarienne du)       28515830.0       28435940.0
# 182                                Viet Nam       96462110.0       97338580.0
# 183                                   Yémen       29161920.0       29825960.0
# 184                                  Zambie       17861030.0       18383960.0
# 185                                Zimbabwe       14645470.0       14862920.0
#
#      Population évolution (%)
# 0                    2.330597
# 1                    1.281493
# 2                   -0.108299
# 3                    1.853504
# 4                    0.319576
# ..                        ...
# 181                 -0.280160
# 182                  0.908616
# 183                  2.277079
# 184                  2.927771
# 185                  1.484759
#
# [186 rows x 4 columns]

# %% [markdown]
# Au tour de la stabilité politique

# %%
stabPrec = stabilite[stabilite['Année'] == (annee-1)]
stabActu = stabilite[stabilite['Année'] == annee]
checkUnusedId(stabPrec, stabActu, 'Pays', 'Pays')
checkUnusedId(stabActu, stabPrec, 'Pays', 'Pays')
print("Tous les pays sont bien restés")

stabPrec['Stabilité Politique ' +
         str(annee-1)] = stabPrec.loc[:, 'Stabilité Politique']
stabActu['Stabilité Politique ' +
         str(annee)] = stabActu.loc[:, 'Stabilité Politique']
stabEvo = pd.merge(stabPrec[['Pays', 'Stabilité Politique '+str(annee-1)]],
                   stabActu[['Pays', 'Stabilité Politique '+str(annee)]], on='Pays')
stabEvo['Stabilité Politique évolution (%)'] = 100*(stabEvo['Stabilité Politique '+str(
    annee)]-stabEvo['Stabilité Politique '+str(annee-1)])/stabEvo['Stabilité Politique '+str(annee-1)]
# Out:
# Auncun Pays non utilisé
# Auncun Pays non utilisé
# Tous les pays sont bien restés
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\1277954364.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stabPrec['Stabilité Politique ' +
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\1277954364.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stabActu['Stabilité Politique ' +

# %%
stabEvo
# Out:
#                                        Pays  Stabilité Politique 2019  \
# 0                               Afghanistan                     -2.66
# 1                            Afrique du Sud                     -0.27
# 2                                   Albanie                      0.11
# 3                                   Algérie                     -1.04
# 4                                 Allemagne                      0.57
# ..                                      ...                       ...
# 194  Venezuela (République bolivarienne du)                     -1.54
# 195                                Viet Nam                      0.03
# 196                                   Yémen                     -2.77
# 197                                  Zambie                     -0.11
# 198                                Zimbabwe                     -0.96
#
#      Stabilité Politique 2020  Stabilité Politique évolution (%)
# 0                       -2.73                           2.631579
# 1                       -0.24                         -11.111111
# 2                        0.08                         -27.272727
# 3                       -0.86                         -17.307692
# 4                        0.67                          17.543860
# ..                        ...                                ...
# 194                     -1.52                          -1.298701
# 195                     -0.07                        -333.333333
# 196                     -2.67                          -3.610108
# 197                     -0.13                          18.181818
# 198                     -1.08                          12.500000
#
# [199 rows x 4 columns]

# %%
stabEvo.describe()
# Out:
#        Stabilité Politique 2019  Stabilité Politique 2020  \
# count                199.000000                199.000000
# mean                  -0.061307                 -0.058945
# std                    0.992725                  0.994801
# min                   -2.770000                 -2.730000
# 25%                   -0.660000                 -0.645000
# 50%                    0.010000                  0.020000
# 75%                    0.770000                  0.780000
# max                    1.880000                  1.910000
#
#        Stabilité Politique évolution (%)
# count                         199.000000
# mean                                 inf
# std                                  NaN
# min                          -333.333333
# 25%                            -8.792271
# 50%                             0.900901
# 75%                            13.288656
# max                                  inf

# %%
stabEvo.replace([np.inf, -np.inf], 0, inplace=True)

# %% [markdown]
# Passons au PIB

# %%
pibPrec = pib[pib['Année'] == (annee-1)]
pibActu = pib[pib['Année'] == annee]
LPaysManquantActu = checkUnusedId(pibPrec, pibActu, 'Pays', 'Pays')
LPaysManquantPrec = checkUnusedId(pibActu, pibPrec, 'Pays', 'Pays')
if len(LPaysManquantActu) != 0:
    print("Il nous manque le PIB du Turkménistan en", annee,
          ", on va donc reprendre celui de l'année précédente")
    for i in LPaysManquantActu:
        pibActu = pd.concat([pibActu, pibPrec.loc[pibPrec['Pays'] == i, :]])
if len(LPaysManquantPrec) != 0:
    print("Il nous manque certains PIB en", annee-1,
          ", on va donc prendre celui de l'année suivante")
    for i in LPaysManquantActu:
        pibPrec = pd.concat([pibPrec, pibActu.loc[pibActu['Pays'] == i, :]])

checkUnusedId(pibPrec, pibActu, 'Pays', 'Pays')

pibPrec['Pib/Habitant ($/habitant) '+str(annee-1)
        ] = pibPrec.loc[:, 'Pib/Habitant ($/habitant)']
pibActu['Pib/Habitant ($/habitant) '+str(annee)
        ] = pibActu.loc[:, 'Pib/Habitant ($/habitant)']
pibEvo = pd.merge(pibPrec[['Pays', 'Pib/Habitant ($/habitant) '+str(annee-1)]],
                  pibActu[['Pays', 'Pib/Habitant ($/habitant) '+str(annee)]], on='Pays')
pibEvo['PIB évolution (%)'] = 100*(pibEvo['Pib/Habitant ($/habitant) '+str(annee)] -
                                   pibEvo['Pib/Habitant ($/habitant) '+str(annee-1)])/pibEvo['Pib/Habitant ($/habitant) '+str(annee-1)]
# Out:
# 1 Pays non utilisé(s) ( 1 ) : ['Turkménistan']
# Auncun Pays non utilisé
# Il nous manque le PIB du Turkménistan en 2020 , on va donc reprendre celui de l'année précédente
# Auncun Pays non utilisé
# C:\Users\thebe\AppData\Local\Temp\ipykernel_8636\3534420031.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pibPrec['Pib/Habitant ($/habitant) '+str(annee-1)

# %%
pibEvo
# Out:
#                                           Pays  \
# 0                                  Afghanistan
# 1                               Afrique du Sud
# 2                                      Albanie
# 3                                      Algérie
# 4                                    Allemagne
# ..                                         ...
# 227  Pays à faible revenu et à déficit vivrier
# 228                       Pays à faible revenu
# 229                        Pays à revenu moyen
# 230                      High-income economies
# 231              Upper-middle-income economies
#
#      Pib/Habitant ($/habitant) 2019  Pib/Habitant ($/habitant) 2020  \
# 0                            2065.0                          1970.6
# 1                           13710.0                         12665.8
# 2                           13653.2                         13253.7
# 3                           11522.0                         10735.4
# 4                           53929.6                         51423.2
# ..                              ...                             ...
# 227                          5371.5                          5081.4
# 228                          1945.1                          1908.2
# 229                          7318.5                          6982.4
# 230                         50435.3                         47815.6
# 231                         19224.5                         18165.8
#
#      PIB évolution (%)
# 0            -4.571429
# 1            -7.616338
# 2            -2.926054
# 3            -6.826940
# 4            -4.647540
# ..                 ...
# 227          -5.400726
# 228          -1.897075
# 229          -4.592471
# 230          -5.194179
# 231          -5.507035
#
# [232 rows x 4 columns]

# %%
part = part[part['Année'] == annee]

# %% [markdown]
# # Fusion des Tables

# %% [markdown]
# Nous allons tout fusionner sur la table "part" (celle contenant les informations sur la part de la viande dans la consommation alimentaire).
# Vérifions donc si des pays apparaissent dans cette table mais pas dans d'autres.

# %%
popEvo
# Out:
#                                        Pays  Population 2019  Population 2020  \
# 0                               Afghanistan       38041750.0       38928350.0
# 1                            Afrique du Sud       58558270.0       59308690.0
# 2                                   Albanie        2880920.0        2877800.0
# 3                                   Algérie       43053050.0       43851040.0
# 4                                 Allemagne       83517040.0       83783940.0
# ..                                      ...              ...              ...
# 181  Venezuela (République bolivarienne du)       28515830.0       28435940.0
# 182                                Viet Nam       96462110.0       97338580.0
# 183                                   Yémen       29161920.0       29825960.0
# 184                                  Zambie       17861030.0       18383960.0
# 185                                Zimbabwe       14645470.0       14862920.0
#
#      Population évolution (%)
# 0                    2.330597
# 1                    1.281493
# 2                   -0.108299
# 3                    1.853504
# 4                    0.319576
# ..                        ...
# 181                 -0.280160
# 182                  0.908616
# 183                  2.277079
# 184                  2.927771
# 185                  1.484759
#
# [186 rows x 4 columns]

# %%
checkUnusedId(part, popEvo, 'Pays', 'Pays')
checkUnusedId(popEvo, part, 'Pays', 'Pays')
EstPrimaire(part, "Pays")
EstPrimaire(popEvo, "Pays")
# Out:
# Auncun Pays non utilisé
# Auncun Pays non utilisé
# La clé est bien unique
# La clé est bien unique

# %%
df = pd.merge(part, popEvo[["Pays", "Population "+str(annee),
              "Population évolution (%)"]], on="Pays", how='inner')

# %%
df
# Out:
#                       Pays  Année  Part de la viande en protéine (%)  \
# 0              Afghanistan   2020                               2.50
# 1           Afrique du Sud   2020                              11.63
# 2                  Albanie   2020                               7.09
# 3                  Algérie   2020                               2.67
# 4                Allemagne   2020                               9.04
# ..                     ...    ...                                ...
# 181    Émirats arabes unis   2020                               6.34
# 182               Équateur   2020                               8.67
# 183  États-Unis d'Amérique   2020                              14.31
# 184               Éthiopie   2020                               1.91
# 185           Îles Salomon   2020                               3.27
#
#      Part de la viande en Kcal (%)  \
# 0                             7.52
# 1                            34.21
# 2                            15.22
# 3                             8.10
# 4                            24.85
# ..                             ...
# 181                          21.70
# 182                          26.72
# 183                          37.02
# 184                           5.09
# 185                           9.68
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2239.0
# 1                                            2855.0
# 2                                            3302.0
# 3                                            3486.0
# 4                                            3630.0
# ..                                              ...
# 181                                          3075.0
# 182                                          2490.0
# 183                                          3920.0
# 184                                          2406.0
# 185                                          2357.0
#
#                              id  import-export (milliers de tonnes)  \
# 0              Afghanistan/2020                                36.0
# 1           Afrique du Sud/2020                               376.0
# 2                  Albanie/2020                                26.0
# 3                  Algérie/2020                                -1.0
# 4                Allemagne/2020                               191.0
# ..                          ...                                 ...
# 181    Émirats arabes unis/2020                               407.0
# 182               Équateur/2020                                 0.0
# 183  États-Unis d'Amérique/2020                             -3743.0
# 184               Éthiopie/2020                                 1.0
# 185           Îles Salomon/2020                                 5.0
#
#      Population 2020  Population évolution (%)
# 0         38928350.0                  2.330597
# 1         59308690.0                  1.281493
# 2          2877800.0                 -0.108299
# 3         43851040.0                  1.853504
# 4         83783940.0                  0.319576
# ..               ...                       ...
# 181        9890400.0                  1.226853
# 182       17643050.0                  1.550566
# 183      331002650.0                  0.588859
# 184      114963590.0                  2.573959
# 185         686880.0                  2.546953
#
# [186 rows x 9 columns]

# %%
df
# Out:
#                       Pays  Année  Part de la viande en protéine (%)  \
# 0              Afghanistan   2020                               2.50
# 1           Afrique du Sud   2020                              11.63
# 2                  Albanie   2020                               7.09
# 3                  Algérie   2020                               2.67
# 4                Allemagne   2020                               9.04
# ..                     ...    ...                                ...
# 181    Émirats arabes unis   2020                               6.34
# 182               Équateur   2020                               8.67
# 183  États-Unis d'Amérique   2020                              14.31
# 184               Éthiopie   2020                               1.91
# 185           Îles Salomon   2020                               3.27
#
#      Part de la viande en Kcal (%)  \
# 0                             7.52
# 1                            34.21
# 2                            15.22
# 3                             8.10
# 4                            24.85
# ..                             ...
# 181                          21.70
# 182                          26.72
# 183                          37.02
# 184                           5.09
# 185                           9.68
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2239.0
# 1                                            2855.0
# 2                                            3302.0
# 3                                            3486.0
# 4                                            3630.0
# ..                                              ...
# 181                                          3075.0
# 182                                          2490.0
# 183                                          3920.0
# 184                                          2406.0
# 185                                          2357.0
#
#                              id  import-export (milliers de tonnes)  \
# 0              Afghanistan/2020                                36.0
# 1           Afrique du Sud/2020                               376.0
# 2                  Albanie/2020                                26.0
# 3                  Algérie/2020                                -1.0
# 4                Allemagne/2020                               191.0
# ..                          ...                                 ...
# 181    Émirats arabes unis/2020                               407.0
# 182               Équateur/2020                                 0.0
# 183  États-Unis d'Amérique/2020                             -3743.0
# 184               Éthiopie/2020                                 1.0
# 185           Îles Salomon/2020                                 5.0
#
#      Population 2020  Population évolution (%)
# 0         38928350.0                  2.330597
# 1         59308690.0                  1.281493
# 2          2877800.0                 -0.108299
# 3         43851040.0                  1.853504
# 4         83783940.0                  0.319576
# ..               ...                       ...
# 181        9890400.0                  1.226853
# 182       17643050.0                  1.550566
# 183      331002650.0                  0.588859
# 184      114963590.0                  2.573959
# 185         686880.0                  2.546953
#
# [186 rows x 9 columns]

# %%
checkUnusedId(df, stabEvo, 'Pays', 'Pays')
checkUnusedId(stabEvo, df, 'Pays', 'Pays')
EstPrimaire(df, 'Pays')
EstPrimaire(stabEvo, 'Pays')

a = 1
# Out:
# 4 Pays non utilisé(s) ( 4 ) : ['Chine' 'Chine, continentale' 'Nouvelle-Calédonie' 'Polynésie française']
# 17 Pays non utilisé(s) ( 17 ) : ['Andorre' 'Bermudes' 'Brunéi Darussalam' 'Érythrée' 'Groenland'
#  'Guinée équatoriale' 'Îles Cook' 'Îles Marshall' 'Nioué' 'Palaos'
#  'Palestine' 'Porto Rico' 'Samoa américaines' 'Singapour' 'Somalie'
#  'Tonga' 'Tuvalu']
# La clé est bien unique
# La clé est bien unique

# %% [markdown]
# On ignore les 17 pays qui apparaissent dans la table stabilité mais qui n'apparaissent pas dans la table part car, on n'a pas les données nécessaires sur ces pays pour mener à bien l'analyse. Pour les 4 autres (ceux qui n'apparaissent pas dans la table stabilité), ils auront la stabilité politique mediane.

# %%
stabEvo
# Out:
#                                        Pays  Stabilité Politique 2019  \
# 0                               Afghanistan                     -2.66
# 1                            Afrique du Sud                     -0.27
# 2                                   Albanie                      0.11
# 3                                   Algérie                     -1.04
# 4                                 Allemagne                      0.57
# ..                                      ...                       ...
# 194  Venezuela (République bolivarienne du)                     -1.54
# 195                                Viet Nam                      0.03
# 196                                   Yémen                     -2.77
# 197                                  Zambie                     -0.11
# 198                                Zimbabwe                     -0.96
#
#      Stabilité Politique 2020  Stabilité Politique évolution (%)
# 0                       -2.73                           2.631579
# 1                       -0.24                         -11.111111
# 2                        0.08                         -27.272727
# 3                       -0.86                         -17.307692
# 4                        0.67                          17.543860
# ..                        ...                                ...
# 194                     -1.52                          -1.298701
# 195                     -0.07                        -333.333333
# 196                     -2.67                          -3.610108
# 197                     -0.13                          18.181818
# 198                     -1.08                          12.500000
#
# [199 rows x 4 columns]

# %%
df = pd.merge(df, stabEvo[['Pays', 'Stabilité Politique '+str(annee),
              'Stabilité Politique évolution (%)']], on='Pays', how='left')

# %%
medPrec = stabEvo['Stabilité Politique '+str(annee-1)].median()
medActu = stabEvo['Stabilité Politique '+str(annee)].median()
df['Stabilité Politique ' +
    str(annee)] = df['Stabilité Politique '+str(annee)].fillna(medActu)
df['Stabilité Politique évolution (%)'] = df['Stabilité Politique évolution (%)'].fillna(
    100*(medActu-medPrec)/medPrec)

# %%
df.describe()
# Out:
#         Année  Part de la viande en protéine (%)  \
# count   186.0                         186.000000
# mean   2020.0                           8.310484
# std       0.0                           4.796896
# min    2020.0                           0.730000
# 25%    2020.0                           4.800000
# 50%    2020.0                           7.980000
# 75%    2020.0                          11.197500
# max    2020.0                          27.400000
#
#        Part de la viande en Kcal (%)  \
# count                     186.000000
# mean                       21.964301
# std                        10.420491
# min                         2.510000
# 25%                        14.360000
# 50%                        22.210000
# 75%                        28.180000
# max                        54.420000
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# count                                      186.000000
# mean                                      2912.887097
# std                                        464.282839
# min                                       1745.000000
# 25%                                       2596.000000
# 50%                                       2917.000000
# 75%                                       3313.250000
# max                                       3920.000000
#
#        import-export (milliers de tonnes)  Population 2020  \
# count                          186.000000     1.860000e+02
# mean                             0.129032     4.957317e+07
# std                            476.915455     1.836376e+08
# min                          -4042.000000     1.082000e+04
# 25%                              1.000000     2.447730e+06
# 50%                             10.000000     9.775375e+06
# 75%                             39.500000     3.120982e+07
# max                           1772.000000     1.471287e+09
#
#        Population évolution (%)  Stabilité Politique 2020  \
# count                186.000000                186.000000
# mean                   1.191570                 -0.111720
# std                    1.052419                  0.941188
# min                   -1.353080                 -2.730000
# 25%                    0.394751                 -0.647500
# 50%                    1.075219                 -0.020000
# 75%                    1.930716                  0.670000
# max                    3.843382                  1.490000
#
#        Stabilité Politique évolution (%)
# count                         186.000000
# mean                           23.463066
# std                           177.104340
# min                          -333.333333
# 25%                            -9.659091
# 50%                             0.000000
# 75%                            16.211878
# max                          1600.000000

# %%
df
# Out:
#                       Pays  Année  Part de la viande en protéine (%)  \
# 0              Afghanistan   2020                               2.50
# 1           Afrique du Sud   2020                              11.63
# 2                  Albanie   2020                               7.09
# 3                  Algérie   2020                               2.67
# 4                Allemagne   2020                               9.04
# ..                     ...    ...                                ...
# 181    Émirats arabes unis   2020                               6.34
# 182               Équateur   2020                               8.67
# 183  États-Unis d'Amérique   2020                              14.31
# 184               Éthiopie   2020                               1.91
# 185           Îles Salomon   2020                               3.27
#
#      Part de la viande en Kcal (%)  \
# 0                             7.52
# 1                            34.21
# 2                            15.22
# 3                             8.10
# 4                            24.85
# ..                             ...
# 181                          21.70
# 182                          26.72
# 183                          37.02
# 184                           5.09
# 185                           9.68
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2239.0
# 1                                            2855.0
# 2                                            3302.0
# 3                                            3486.0
# 4                                            3630.0
# ..                                              ...
# 181                                          3075.0
# 182                                          2490.0
# 183                                          3920.0
# 184                                          2406.0
# 185                                          2357.0
#
#                              id  import-export (milliers de tonnes)  \
# 0              Afghanistan/2020                                36.0
# 1           Afrique du Sud/2020                               376.0
# 2                  Albanie/2020                                26.0
# 3                  Algérie/2020                                -1.0
# 4                Allemagne/2020                               191.0
# ..                          ...                                 ...
# 181    Émirats arabes unis/2020                               407.0
# 182               Équateur/2020                                 0.0
# 183  États-Unis d'Amérique/2020                             -3743.0
# 184               Éthiopie/2020                                 1.0
# 185           Îles Salomon/2020                                 5.0
#
#      Population 2020  Population évolution (%)  Stabilité Politique 2020  \
# 0         38928350.0                  2.330597                     -2.73
# 1         59308690.0                  1.281493                     -0.24
# 2          2877800.0                 -0.108299                      0.08
# 3         43851040.0                  1.853504                     -0.86
# 4         83783940.0                  0.319576                      0.67
# ..               ...                       ...                       ...
# 181        9890400.0                  1.226853                      0.63
# 182       17643050.0                  1.550566                     -0.36
# 183      331002650.0                  0.588859                     -0.02
# 184      114963590.0                  2.573959                     -1.74
# 185         686880.0                  2.546953                      0.64
#
#      Stabilité Politique évolution (%)
# 0                             2.631579
# 1                           -11.111111
# 2                           -27.272727
# 3                           -17.307692
# 4                            17.543860
# ..                                 ...
# 181                          -8.695652
# 182                          56.521739
# 183                        -115.384615
# 184                          32.824427
# 185                          25.490196
#
# [186 rows x 11 columns]

# %%
pibEvo
# Out:
#                                           Pays  \
# 0                                  Afghanistan
# 1                               Afrique du Sud
# 2                                      Albanie
# 3                                      Algérie
# 4                                    Allemagne
# ..                                         ...
# 227  Pays à faible revenu et à déficit vivrier
# 228                       Pays à faible revenu
# 229                        Pays à revenu moyen
# 230                      High-income economies
# 231              Upper-middle-income economies
#
#      Pib/Habitant ($/habitant) 2019  Pib/Habitant ($/habitant) 2020  \
# 0                            2065.0                          1970.6
# 1                           13710.0                         12665.8
# 2                           13653.2                         13253.7
# 3                           11522.0                         10735.4
# 4                           53929.6                         51423.2
# ..                              ...                             ...
# 227                          5371.5                          5081.4
# 228                          1945.1                          1908.2
# 229                          7318.5                          6982.4
# 230                         50435.3                         47815.6
# 231                         19224.5                         18165.8
#
#      PIB évolution (%)
# 0            -4.571429
# 1            -7.616338
# 2            -2.926054
# 3            -6.826940
# 4            -4.647540
# ..                 ...
# 227          -5.400726
# 228          -1.897075
# 229          -4.592471
# 230          -5.194179
# 231          -5.507035
#
# [232 rows x 4 columns]

# %%
checkUnusedId(df, pibEvo, 'Pays', 'Pays')
checkUnusedId(pibEvo, df, 'Pays', 'Pays')
a = 1
# Out:
# 10 Pays non utilisé(s) ( 10 ) : ['Chine, Taiwan Province de' 'Chine, continentale' 'Cuba'
#  'Nouvelle-Calédonie' 'Polynésie française' 'République arabe syrienne'
#  'République populaire démocratique de Corée' 'Soudan du Sud'
#  'Venezuela (République bolivarienne du)' 'Yémen']
# 56 Pays non utilisé(s) ( 56 ) : ['Bermudes' 'Brunéi Darussalam' 'Guinée équatoriale' 'Îles Marshall'
#  'Palaos' 'Palestine' 'Porto Rico' 'Singapour' 'Somalie' 'Tonga' 'Tuvalu'
#  'Monde' 'Afrique' 'Afrique orientale' 'Afrique centrale'
#  'Afrique septentrionale' 'Afrique du Nord (Soudan Excl)'
#  'Afrique australe' 'Afrique occidentale' 'Afrique subsaharienne'
#  'Afrique subsaharienne (y compris Soudan)' 'Amérique du Nord et Europe'
#  'Amérique septentrionale' 'Europe' 'Europe orientale'
#  'Europe septentrionale' 'Europe méridionale' 'Europe occidentale'
#  'Amérique latine et Caraïbes' 'Amérique centrale' 'Caraïbes'
#  'Amérique du Sud' 'Asie' 'Asie centrale' 'Asie orientale'
#  'Asie méridionale' 'Asie du Sud (Inde Excl)' 'Asie du Sud-Est'
#  'Asie occidentale' 'Asie centrale et Asie du Sud'
#  'Asie orientale et Asie du Sud-Est' 'Asie occidentale et Afrique du Nord'
#  'Océanie' 'Australie et Nouvelle-Zélande' 'Mélanésie' 'Micronésie'
#  'Polynésie' 'Océanie, hors Australie et Nouvelle-Zélande'
#  'Pays les moins développés' 'Pays sans littoral en voie de développement'
#  'Petites îles en voie de Développement'
#  'Pays à faible revenu et à déficit vivrier' 'Pays à faible revenu'
#  'Pays à revenu moyen' 'High-income economies'
#  'Upper-middle-income economies']

# %% [markdown]
# Encore une fois, on ignore les 66 pays qui n'apparaissent pas dans une table ou dans l'autre. Sauf la chine auquelle on rajoute manuellement son PIB

# %%
pibChine = pd.read_csv(
    'data\OCDE_PIB_Chine_2018_2020.csv').query('LOCATION=="CHN"')
pibChine
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 124      CHN       GDP     TOT  USD_CAP         A  2018  15466.329982
# 125      CHN       GDP     TOT  USD_CAP         A  2019  16624.520609
# 126      CHN       GDP     TOT  USD_CAP         A  2020  17176.865661
# 127      CHN       GDP     TOT  USD_CAP         A  2021  19334.953602
#
#     Flag Codes
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN

# %%
PIB_CHN_prec = pibChine.query('TIME==(@annee-1)')['Value'].iloc[0]
PIB_CHN_actu = pibChine.query('TIME==(@annee)')['Value'].iloc[0]
ligne = ['Chine, continentale', PIB_CHN_prec, PIB_CHN_actu,
         100*(PIB_CHN_actu-PIB_CHN_prec)/PIB_CHN_prec]
colonne = ['Pays', 'Pib/Habitant ($/habitant) '+str(annee-1),
           'Pib/Habitant ($/habitant) '+str(annee), 'PIB évolution (%)']
ligne = pd.DataFrame([ligne], columns=colonne)
pibEvo = pd.concat([pibEvo, ligne], ignore_index=True)

# %%
checkUnusedId(df, pibEvo, 'Pays', 'Pays')
df = pd.merge(df, pibEvo[['Pays', 'Pib/Habitant ($/habitant) ' +
              str(annee), 'PIB évolution (%)']], on='Pays', how='inner')
# Out:
# 9 Pays non utilisé(s) ( 9 ) : ['Chine, Taiwan Province de' 'Cuba' 'Nouvelle-Calédonie'
#  'Polynésie française' 'République arabe syrienne'
#  'République populaire démocratique de Corée' 'Soudan du Sud'
#  'Venezuela (République bolivarienne du)' 'Yémen']

# %%
df
# Out:
#                       Pays  Année  Part de la viande en protéine (%)  \
# 0              Afghanistan   2020                               2.50
# 1           Afrique du Sud   2020                              11.63
# 2                  Albanie   2020                               7.09
# 3                  Algérie   2020                               2.67
# 4                Allemagne   2020                               9.04
# ..                     ...    ...                                ...
# 172    Émirats arabes unis   2020                               6.34
# 173               Équateur   2020                               8.67
# 174  États-Unis d'Amérique   2020                              14.31
# 175               Éthiopie   2020                               1.91
# 176           Îles Salomon   2020                               3.27
#
#      Part de la viande en Kcal (%)  \
# 0                             7.52
# 1                            34.21
# 2                            15.22
# 3                             8.10
# 4                            24.85
# ..                             ...
# 172                          21.70
# 173                          26.72
# 174                          37.02
# 175                           5.09
# 176                           9.68
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2239.0
# 1                                            2855.0
# 2                                            3302.0
# 3                                            3486.0
# 4                                            3630.0
# ..                                              ...
# 172                                          3075.0
# 173                                          2490.0
# 174                                          3920.0
# 175                                          2406.0
# 176                                          2357.0
#
#                              id  import-export (milliers de tonnes)  \
# 0              Afghanistan/2020                                36.0
# 1           Afrique du Sud/2020                               376.0
# 2                  Albanie/2020                                26.0
# 3                  Algérie/2020                                -1.0
# 4                Allemagne/2020                               191.0
# ..                          ...                                 ...
# 172    Émirats arabes unis/2020                               407.0
# 173               Équateur/2020                                 0.0
# 174  États-Unis d'Amérique/2020                             -3743.0
# 175               Éthiopie/2020                                 1.0
# 176           Îles Salomon/2020                                 5.0
#
#      Population 2020  Population évolution (%)  Stabilité Politique 2020  \
# 0         38928350.0                  2.330597                     -2.73
# 1         59308690.0                  1.281493                     -0.24
# 2          2877800.0                 -0.108299                      0.08
# 3         43851040.0                  1.853504                     -0.86
# 4         83783940.0                  0.319576                      0.67
# ..               ...                       ...                       ...
# 172        9890400.0                  1.226853                      0.63
# 173       17643050.0                  1.550566                     -0.36
# 174      331002650.0                  0.588859                     -0.02
# 175      114963590.0                  2.573959                     -1.74
# 176         686880.0                  2.546953                      0.64
#
#      Stabilité Politique évolution (%)  Pib/Habitant ($/habitant) 2020  \
# 0                             2.631579                          1970.6
# 1                           -11.111111                         12665.8
# 2                           -27.272727                         13253.7
# 3                           -17.307692                         10735.4
# 4                            17.543860                         51423.2
# ..                                 ...                             ...
# 172                          -8.695652                         63299.4
# 173                          56.521739                         10325.0
# 174                        -115.384615                         59755.2
# 175                          32.824427                          2296.9
# 176                          25.490196                          2482.4
#
#      PIB évolution (%)
# 0            -4.571429
# 1            -7.616338
# 2            -2.926054
# 3            -6.826940
# 4            -4.647540
# ..                 ...
# 172          -7.272240
# 173          -9.195645
# 174          -4.328613
# 175           3.398758
# 176          -6.694230
#
# [177 rows x 13 columns]

# %% [markdown]
# Ajoutons la production de volailles

# %%
prodVolail = prodVolail.loc[prodVolail['Année'] == annee, :]
prodVolail
# Out:
# Produit                   Pays  Année  Tonnes de viande de poulet produite  \
# 2                  Afghanistan   2020                             27753.95
# 5               Afrique du Sud   2020                           1880000.00
# 8                      Albanie   2020                             12233.91
# 11                     Algérie   2020                            257787.09
# 14                   Allemagne   2020                           1066000.00
# ..                         ...    ...                                  ...
# 574                   Érythrée   2020                              1128.61
# 577      États-Unis d'Amérique   2020                          20514868.64
# 580                   Éthiopie   2020                             67650.74
# 583                  Îles Cook   2020                                15.88
# 586               Îles Salomon   2020                               283.68
#
# Produit  Milliers de poulets                          id
# 2                    13697.0            Afghanistan/2020
# 5                   170487.0         Afrique du Sud/2020
# 8                     6774.0                Albanie/2020
# 11                  136415.0                Algérie/2020
# 14                   19351.0              Allemagne/2020
# ..                       ...                         ...
# 574                   1185.0               Érythrée/2020
# 577                1537000.0  États-Unis d'Amérique/2020
# 580                  56993.0               Éthiopie/2020
# 583                     17.0              Îles Cook/2020
# 586                    245.0           Îles Salomon/2020
#
# [194 rows x 5 columns]

# %%
checkUnusedId(df, prodVolail, 'Pays', 'Pays')
# Out:
# 4 Pays non utilisé(s) ( 4 ) : ['Djibouti' 'Maldives' 'Roumanie' 'Slovaquie']
# ['Djibouti', 'Maldives', 'Roumanie', 'Slovaquie']

# %% [markdown]
# On ignore le pays auquelle on a pas accès à la production

# %%
df = pd.merge(df, prodVolail[['Pays', 'Tonnes de viande de poulet produite',
              'Milliers de poulets']], on='Pays', how='inner')

# %% [markdown]
# Colonne Suplémentaire

# %% [markdown]
# Ajoutons le PIB du Pays

# %%
df['PIB'] = df['Population '+str(annee)] * \
    df['Pib/Habitant ($/habitant) '+str(annee)]

# %%
df
# Out:
#                       Pays  Année  Part de la viande en protéine (%)  \
# 0              Afghanistan   2020                               2.50
# 1           Afrique du Sud   2020                              11.63
# 2                  Albanie   2020                               7.09
# 3                  Algérie   2020                               2.67
# 4                Allemagne   2020                               9.04
# ..                     ...    ...                                ...
# 168    Émirats arabes unis   2020                               6.34
# 169               Équateur   2020                               8.67
# 170  États-Unis d'Amérique   2020                              14.31
# 171               Éthiopie   2020                               1.91
# 172           Îles Salomon   2020                               3.27
#
#      Part de la viande en Kcal (%)  \
# 0                             7.52
# 1                            34.21
# 2                            15.22
# 3                             8.10
# 4                            24.85
# ..                             ...
# 168                          21.70
# 169                          26.72
# 170                          37.02
# 171                           5.09
# 172                           9.68
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2239.0
# 1                                            2855.0
# 2                                            3302.0
# 3                                            3486.0
# 4                                            3630.0
# ..                                              ...
# 168                                          3075.0
# 169                                          2490.0
# 170                                          3920.0
# 171                                          2406.0
# 172                                          2357.0
#
#                              id  import-export (milliers de tonnes)  \
# 0              Afghanistan/2020                                36.0
# 1           Afrique du Sud/2020                               376.0
# 2                  Albanie/2020                                26.0
# 3                  Algérie/2020                                -1.0
# 4                Allemagne/2020                               191.0
# ..                          ...                                 ...
# 168    Émirats arabes unis/2020                               407.0
# 169               Équateur/2020                                 0.0
# 170  États-Unis d'Amérique/2020                             -3743.0
# 171               Éthiopie/2020                                 1.0
# 172           Îles Salomon/2020                                 5.0
#
#      Population 2020  Population évolution (%)  Stabilité Politique 2020  \
# 0         38928350.0                  2.330597                     -2.73
# 1         59308690.0                  1.281493                     -0.24
# 2          2877800.0                 -0.108299                      0.08
# 3         43851040.0                  1.853504                     -0.86
# 4         83783940.0                  0.319576                      0.67
# ..               ...                       ...                       ...
# 168        9890400.0                  1.226853                      0.63
# 169       17643050.0                  1.550566                     -0.36
# 170      331002650.0                  0.588859                     -0.02
# 171      114963590.0                  2.573959                     -1.74
# 172         686880.0                  2.546953                      0.64
#
#      Stabilité Politique évolution (%)  Pib/Habitant ($/habitant) 2020  \
# 0                             2.631579                          1970.6
# 1                           -11.111111                         12665.8
# 2                           -27.272727                         13253.7
# 3                           -17.307692                         10735.4
# 4                            17.543860                         51423.2
# ..                                 ...                             ...
# 168                          -8.695652                         63299.4
# 169                          56.521739                         10325.0
# 170                        -115.384615                         59755.2
# 171                          32.824427                          2296.9
# 172                          25.490196                          2482.4
#
#      PIB évolution (%)  Tonnes de viande de poulet produite  \
# 0            -4.571429                             27753.95
# 1            -7.616338                           1880000.00
# 2            -2.926054                             12233.91
# 3            -6.826940                            257787.09
# 4            -4.647540                           1066000.00
# ..                 ...                                  ...
# 168          -7.272240                             54101.00
# 169          -9.195645                            452047.00
# 170          -4.328613                          20514868.64
# 171           3.398758                             67650.74
# 172          -6.694230                               283.68
#
#      Milliers de poulets           PIB
# 0                13697.0  7.671221e+10
# 1               170487.0  7.511920e+11
# 2                 6774.0  3.814150e+10
# 3               136415.0  4.707585e+11
# 4                19351.0  4.308438e+12
# ..                   ...           ...
# 168              25401.0  6.260564e+11
# 169             171642.0  1.821645e+11
# 170            1537000.0  1.977913e+13
# 171              56993.0  2.640599e+11
# 172                245.0  1.705111e+09
#
# [173 rows x 16 columns]

# %%
df.describe().round(3)
# Out:
#         Année  Part de la viande en protéine (%)  \
# count   173.0                            173.000
# mean   2020.0                              8.353
# std       0.0                              4.819
# min    2020.0                              0.730
# 25%    2020.0                              4.830
# 50%    2020.0                              8.100
# 75%    2020.0                             11.200
# max    2020.0                             27.400
#
#        Part de la viande en Kcal (%)  \
# count                        173.000
# mean                          22.044
# std                           10.429
# min                            2.510
# 25%                           15.140
# 50%                           22.240
# 75%                           28.120
# max                           54.420
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# count                                         173.000
# mean                                         2927.301
# std                                           459.546
# min                                          1745.000
# 25%                                          2609.000
# 50%                                          2926.000
# 75%                                          3326.000
# max                                          3920.000
#
#        import-export (milliers de tonnes)  Population 2020  \
# count                             173.000     1.730000e+02
# mean                               -5.613     5.228866e+07
# std                               493.029     1.901486e+08
# min                             -4042.000     1.082000e+04
# 25%                                 1.000     2.540910e+06
# 50%                                 9.000     9.537650e+06
# 75%                                36.000     3.297185e+07
# max                              1772.000     1.471287e+09
#
#        Population évolution (%)  Stabilité Politique 2020  \
# count                   173.000                   173.000
# mean                      1.220                    -0.081
# std                       1.053                     0.906
# min                      -1.353                    -2.730
# 25%                       0.436                    -0.640
# 50%                       1.090                    -0.020
# 75%                       1.947                     0.710
# max                       3.843                     1.490
#
#        Stabilité Politique évolution (%)  Pib/Habitant ($/habitant) 2020  \
# count                            173.000                         173.000
# mean                              16.770                       19356.700
# std                              156.841                       19506.738
# min                             -333.333                         731.100
# 25%                              -11.594                        4857.400
# 50%                                0.962                       12619.900
# 75%                               14.286                       27077.000
# max                             1600.000                      112557.000
#
#        PIB évolution (%)  Tonnes de viande de poulet produite  \
# count            173.000                         1.730000e+02
# mean              -5.768                         7.716906e+05
# std                7.609                         2.521102e+06
# min              -54.642                         0.000000e+00
# 25%               -8.312                         1.053641e+04
# 50%               -4.734                         7.328970e+04
# 75%               -2.440                         3.127531e+05
# max               42.789                         2.051487e+07
#
#        Milliers de poulets           PIB
# count              173.000  1.730000e+02
# mean            172756.936  8.594648e+11
# std             642106.729  3.127808e+12
# min                  5.000  1.470741e+08
# 25%               4674.000  2.886327e+10
# 50%              20696.000  9.694126e+10
# 75%              82599.000  4.192131e+11
# max            5196760.000  2.472307e+13

# %% [markdown]
# Renommons les colonnes afin de simplifier l'analyse

# %%
df = df.rename(columns={"Part de la viande en protéine (%)": "part_proteine_viande",
                        "Part de la viande en Kcal (%)": "part_Kcal_viande",
                        "Disponibilité alimentaire (Kcal/personne/jour)": "dispo_alim",
                        "import-export (milliers de tonnes)": "imp_exp",
                        "Population "+str(annee): "population",
                        "Population évolution (%)": "population_evo",
                        "Stabilité Politique "+str(annee): "stab_pol",
                        "Stabilité Politique évolution (%)": "stab_pol_evo",
                        "Pib/Habitant ($/habitant) "+str(annee): "pib_hab",
                        "PIB évolution (%)": "pib_evo",
                        "PIB": "pib",
                        "Tonnes de viande de poulet produite": "poulet_pdt",
                        "Milliers de poulets": "nb_poulets"})
df
# Out:
#                       Pays  Année  part_proteine_viande  part_Kcal_viande  \
# 0              Afghanistan   2020                  2.50              7.52
# 1           Afrique du Sud   2020                 11.63             34.21
# 2                  Albanie   2020                  7.09             15.22
# 3                  Algérie   2020                  2.67              8.10
# 4                Allemagne   2020                  9.04             24.85
# ..                     ...    ...                   ...               ...
# 168    Émirats arabes unis   2020                  6.34             21.70
# 169               Équateur   2020                  8.67             26.72
# 170  États-Unis d'Amérique   2020                 14.31             37.02
# 171               Éthiopie   2020                  1.91              5.09
# 172           Îles Salomon   2020                  3.27              9.68
#
#      dispo_alim                          id  imp_exp   population  \
# 0        2239.0            Afghanistan/2020     36.0   38928350.0
# 1        2855.0         Afrique du Sud/2020    376.0   59308690.0
# 2        3302.0                Albanie/2020     26.0    2877800.0
# 3        3486.0                Algérie/2020     -1.0   43851040.0
# 4        3630.0              Allemagne/2020    191.0   83783940.0
# ..          ...                         ...      ...          ...
# 168      3075.0    Émirats arabes unis/2020    407.0    9890400.0
# 169      2490.0               Équateur/2020      0.0   17643050.0
# 170      3920.0  États-Unis d'Amérique/2020  -3743.0  331002650.0
# 171      2406.0               Éthiopie/2020      1.0  114963590.0
# 172      2357.0           Îles Salomon/2020      5.0     686880.0
#
#      population_evo  stab_pol  stab_pol_evo  pib_hab   pib_evo   poulet_pdt  \
# 0          2.330597     -2.73      2.631579   1970.6 -4.571429     27753.95
# 1          1.281493     -0.24    -11.111111  12665.8 -7.616338   1880000.00
# 2         -0.108299      0.08    -27.272727  13253.7 -2.926054     12233.91
# 3          1.853504     -0.86    -17.307692  10735.4 -6.826940    257787.09
# 4          0.319576      0.67     17.543860  51423.2 -4.647540   1066000.00
# ..              ...       ...           ...      ...       ...          ...
# 168        1.226853      0.63     -8.695652  63299.4 -7.272240     54101.00
# 169        1.550566     -0.36     56.521739  10325.0 -9.195645    452047.00
# 170        0.588859     -0.02   -115.384615  59755.2 -4.328613  20514868.64
# 171        2.573959     -1.74     32.824427   2296.9  3.398758     67650.74
# 172        2.546953      0.64     25.490196   2482.4 -6.694230       283.68
#
#      nb_poulets           pib
# 0       13697.0  7.671221e+10
# 1      170487.0  7.511920e+11
# 2        6774.0  3.814150e+10
# 3      136415.0  4.707585e+11
# 4       19351.0  4.308438e+12
# ..          ...           ...
# 168     25401.0  6.260564e+11
# 169    171642.0  1.821645e+11
# 170   1537000.0  1.977913e+13
# 171     56993.0  2.640599e+11
# 172       245.0  1.705111e+09
#
# [173 rows x 16 columns]

# %%
# On retire la Chine car il s'agit ici de la zone géographique et non du pays
df = df.query("Pays != 'Chine'")

# %%
df.to_parquet('data\Table_Finale.parquet', index=False)
